# %% [markdown]
# # Preprocess MRI
# ## Packages

# %%
import pydicom as dicom
import numpy as np
import matplotlib.pyplot as plt
import os
import nibabel as nib
from ipywidgets import interact
from matplotlib.colors import ListedColormap
from azureml.core import Workspace, Dataset, Datastore
import os

# %% [markdown]
# ### Helper Functions

# %%
slice_description_to_use = ['t1_tse_cor', 't1_tse_fs_cor', 't1_tse_sag', 't2_tse_fs_cor','t2_tse_fs_sag']
def get_mri_slices_from_path(path,slice_descriptions = slice_description_to_use):
    path_list = os.listdir(path)
    slices = []
    for dcm_path in path_list:
        try:
            slice = dicom.dcmread(path + "/" + dcm_path) 
            if slice.SeriesDescription in slice_descriptions:
                slices.append(slice)
            else: 
                pass
        except:
            pass
    return slices

def get_slice_descriptions(slices):
    names = [ds.SeriesDescription for ds in slices]
    print(np.unique(names,return_counts=True))

def slices_sort_and_selectet(slices,slice_type):
    slices.sort(key=lambda x: int(x.SliceLocation))
    type_ = [slic.SeriesDescription == slice_type for slic in slices]
    slice_one_type = np.array(slices)[type_]
    return slice_one_type

def visualize_slices(slices):
    cmap = plt.cm.winter
    # Get the colormap colors
    my_cmap = cmap(np.arange(cmap.N))
    my_cmap[:,-1] = np.linspace(0, 1, cmap.N)
    my_cmap = ListedColormap(my_cmap)

    # Visualize Images as a slider
    def show_slice(i):
        plt.imshow(slices[i].pixel_array, cmap='gray')
        plt.show()
    interact(show_slice, i=(0, len(slices)-1))

def pad_array(original_array,axis,padd_size):
    # Calculate padding
    total_padding = padd_size - 15 
    padding_before = total_padding // 2 
    padding_after = total_padding - padding_before
    if axis == 0:
        padding = ((padding_before, padding_after),(0, 0), (0, 0))
    elif axis == 1:
        padding = ((0, 0),(padding_before, padding_after), (0, 0))
    elif axis == 2:
        padding = ((0, 0),(0, 0), (padding_before, padding_after))
    # Pad the array
    padded_array = np.pad(
        original_array,
        padding,
        mode='constant',
        constant_values=0
    )
    return padded_array

# %%
subscription_id = '35068096-667c-4620-8bb2-6b050765fd4e'
resource_group = 'ComputeFHNW'
workspace_name = 'FHNW'
workspace = Workspace(subscription_id, resource_group, workspace_name)
datastore = Datastore.get(workspace, "mrialldata")
dataset = Dataset.File.from_files(path=(datastore, 'output.deid/images/'))
mount_context = dataset.mount()
mount_context.start()
files = next(os.walk(mount_context.mount_point))[1]
mount_context.stop()

# %%
file = str(files[0])
def download_file(file):
    subscription_id = '35068096-667c-4620-8bb2-6b050765fd4e'
    resource_group = 'ComputeFHNW'
    workspace_name = 'FHNW'
    workspace = Workspace(subscription_id, resource_group, workspace_name) 
    datastore = Datastore.get(workspace, "mrialldata")
    dataset = Dataset.File.from_files(path=(datastore, 'output.deid/images/' + file))
    dataset.download(target_path='./raw_data/downloaded_mri_files/' + file, overwrite=True)

get_slices = lambda path: get_mri_slices_from_path(f"./raw_data/downloaded_mri_files/{path}/")

# %%
get_slices(file)
# Out:
# [Dataset.file_meta -------------------------------
#  (0002, 0000) File Meta Information Group Length  UL: 196
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.19.45302.2016061815295718478527545
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.6
#  (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_366'
#  -------------------------------------------------
#  (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
#  (0008, 0012) Instance Creation Date              DA: '20160618'
#  (0008, 0013) Instance Creation Time              TM: '153000.066000'
#  (0008, 0016) SOP Class UID                       UI: MR Image Storage
#  (0008, 0018) SOP Instance UID                    UI: w5_pkphZu75u2QU7AXEwn0gyEfzxi0A9YsBZoWx3cy0=
#  (0008, 0020) Study Date                          DA: '20160618'
#  (0008, 0021) Series Date                         DA: '20160618'
#  (0008, 0022) Acquisition Date                    DA: '20160618'
#  (0008, 0023) Content Date                        DA: '20160618'
#  (0008, 0030) Study Time                          TM: '152114.745000'
#  (0008, 0031) Series Time                         TM: '153000.061000'
#  (0008, 0032) Acquisition Time                    TM: '152503.830000'
#  (0008, 0033) Content Time                        TM: '153000.066000'
#  (0008, 0050) Accession Number                    SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0008, 0060) Modality                            CS: 'MR'
#  (0008, 0070) Manufacturer                        LO: 'SIEMENS'
#  (0008, 1010) Station Name                        SH: 'KSA33801'
#  (0008, 1030) Study Description                   LO: 'MR Hypophyse'
#  (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#     (0008, 0100) Code Value                          SH: 'MNDSHYP'
#     (0008, 0102) Coding Scheme Designator            SH: 'L'
#     (0008, 0104) Code Meaning                        LO: 'MR Hypophyse'
#     ---------
#  (0008, 103e) Series Description                  LO: 't1_tse_sag'
#  (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
#  (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#     ---------
#  (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: hftXsteDt1i7G90yzzxbi9monIJwZd5iBQMUNAyPyCA=
#     ---------
#  (0008, 1140)  Referenced Image Sequence  3 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: xlvmirMT72APq-niAJSdNqzd7O6x0tsvuMoA0X-pu7c=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 3V47tC-BvUTwoqBk9oRXFs7zhz3ernDaQXOiThncUBk=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#     ---------
#  (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#  (0010, 0020) Patient ID                          LO: 'cxhGTPfptFa_593Kas1wi7iGmnu2nKbklSXoebANACc='
#  (0010, 0040) Patient's Sex                       CS: 'F'
#  (0010, 1010) Patient's Age                       AS: '060Y'
#  (0010, 1020) Patient's Size                      DS: '1.57'
#  (0010, 1030) Patient's Weight                    DS: '81.0'
#  (0010, 21c0) Pregnancy Status                    US: 4
#  (0012, 0062) Patient Identity Removed            CS: 'Yes'
#  (0018, 0015) Body Part Examined                  CS: 'BRAIN'
#  (0018, 0020) Scanning Sequence                   CS: 'SE'
#  (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
#  (0018, 0022) Scan Options                        CS: 'SAT1'
#  (0018, 0023) MR Acquisition Type                 CS: '2D'
#  (0018, 0024) Sequence Name                       SH: '*tse2d1_3'
#  (0018, 0025) Angio Flag                          CS: 'N'
#  (0018, 0050) Slice Thickness                     DS: '2.5'
#  (0018, 0080) Repetition Time                     DS: '701.0'
#  (0018, 0081) Echo Time                           DS: '11.0'
#  (0018, 0083) Number of Averages                  DS: '3.0'
#  (0018, 0084) Imaging Frequency                   DS: '123.202865'
#  (0018, 0085) Imaged Nucleus                      SH: '1H'
#  (0018, 0086) Echo Number(s)                      IS: '1'
#  (0018, 0087) Magnetic Field Strength             DS: '3.0'
#  (0018, 0088) Spacing Between Slices              DS: '2.625'
#  (0018, 0089) Number of Phase Encoding Steps      IS: '411'
#  (0018, 0091) Echo Train Length                   IS: '3'
#  (0018, 0093) Percent Sampling                    DS: '100.0'
#  (0018, 0094) Percent Phase Field of View         DS: '100.0'
#  (0018, 0095) Pixel Bandwidth                     DS: '355.0'
#  (0018, 1000) Device Serial Number                LO: '45302'
#  (0018, 1020) Software Versions                   LO: 'syngo MR E11'
#  (0018, 1030) Protocol Name                       LO: 't1_tse_sag'
#  (0018, 1251) Transmit Coil Name                  SH: 'Body'
#  (0018, 1310) Acquisition Matrix                  US: [0, 256, 256, 0]
#  (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
#  (0018, 1314) Flip Angle                          DS: '120.0'
#  (0018, 1315) Variable Flip Angle Flag            CS: 'N'
#  (0018, 1316) SAR                                 DS: '0.51975795973104'
#  (0018, 1318) dB/dt                               DS: '0.0'
#  (0018, 5100) Patient Position                    CS: 'HFS'
#  (0020, 000d) Study Instance UID                  UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#  (0020, 000e) Series Instance UID                 UI: MF-KdaI_mhQcpJTARMSnVyZb7E3f_r8BydrO6Ir7esE=
#  (0020, 0010) Study ID                            SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0020, 0011) Series Number                       IS: '7'
#  (0020, 0012) Acquisition Number                  IS: '1'
#  (0020, 0013) Instance Number                     IS: '13'
#  (0020, 0032) Image Position (Patient)            DS: [-22.821022210103, -88.295800266816, 76.084577920674]
#  (0020, 0037) Image Orientation (Patient)         DS: [0.10712895011114, 0.99214866458433, 0.06453228193409, 0.00578426725438, 0.06428277267649, -0.9979149599988]
#  (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.19.45302.1.20160618152114898.0.0.0
#  (0020, 1040) Position Reference Indicator        LO: ''
#  (0020, 1041) Slice Location                      DS: '-13.304355791822'
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.3125, 0.3125]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 12
#  (0028, 0102) High Bit                            US: 11
#  (0028, 0103) Pixel Representation                US: 0
#  (0028, 0106) Smallest Image Pixel Value          US: 0
#  (0028, 0107) Largest Image Pixel Value           US: 1104
#  (0028, 1050) Window Center                       DS: '359.0'
#  (0028, 1051) Window Width                        DS: '807.0'
#  (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
#  (0040, 0244) Performed Procedure Step Start Date DA: '20160618'
#  (0040, 0245) Performed Procedure Step Start Time TM: '152114.827000'
#  (0040, 0253) Performed Procedure Step ID         SH: '7013955'
#  (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hypophyse'
#  (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#     (0040, 1001) Requested Procedure ID              SH: '7013955'
#     ---------
#  (0040, 0280) Comments on the Performed Procedure ST: ''
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0000) File Meta Information Group Length  UL: 196
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.19.45302.2016061815295720312427548
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.6
#  (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_366'
#  -------------------------------------------------
#  (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
#  (0008, 0012) Instance Creation Date              DA: '20160618'
#  (0008, 0013) Instance Creation Time              TM: '153000.089000'
#  (0008, 0016) SOP Class UID                       UI: MR Image Storage
#  (0008, 0018) SOP Instance UID                    UI: IF79WJ950e_pPYukfbkPEwKFzJ-Iqq8wj8zBv4Honkc=
#  (0008, 0020) Study Date                          DA: '20160618'
#  (0008, 0021) Series Date                         DA: '20160618'
#  (0008, 0022) Acquisition Date                    DA: '20160618'
#  (0008, 0023) Content Date                        DA: '20160618'
#  (0008, 0030) Study Time                          TM: '152114.745000'
#  (0008, 0031) Series Time                         TM: '153000.061000'
#  (0008, 0032) Acquisition Time                    TM: '152504.157500'
#  (0008, 0033) Content Time                        TM: '153000.089000'
#  (0008, 0050) Accession Number                    SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0008, 0060) Modality                            CS: 'MR'
#  (0008, 0070) Manufacturer                        LO: 'SIEMENS'
#  (0008, 1010) Station Name                        SH: 'KSA33801'
#  (0008, 1030) Study Description                   LO: 'MR Hypophyse'
#  (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#     (0008, 0100) Code Value                          SH: 'MNDSHYP'
#     (0008, 0102) Coding Scheme Designator            SH: 'L'
#     (0008, 0104) Code Meaning                        LO: 'MR Hypophyse'
#     ---------
#  (0008, 103e) Series Description                  LO: 't1_tse_sag'
#  (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
#  (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#     ---------
#  (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: hftXsteDt1i7G90yzzxbi9monIJwZd5iBQMUNAyPyCA=
#     ---------
#  (0008, 1140)  Referenced Image Sequence  3 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: xlvmirMT72APq-niAJSdNqzd7O6x0tsvuMoA0X-pu7c=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 3V47tC-BvUTwoqBk9oRXFs7zhz3ernDaQXOiThncUBk=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#     ---------
#  (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#  (0010, 0020) Patient ID                          LO: 'cxhGTPfptFa_593Kas1wi7iGmnu2nKbklSXoebANACc='
#  (0010, 0040) Patient's Sex                       CS: 'F'
#  (0010, 1010) Patient's Age                       AS: '060Y'
#  (0010, 1020) Patient's Size                      DS: '1.57'
#  (0010, 1030) Patient's Weight                    DS: '81.0'
#  (0010, 21c0) Pregnancy Status                    US: 4
#  (0012, 0062) Patient Identity Removed            CS: 'Yes'
#  (0018, 0015) Body Part Examined                  CS: 'BRAIN'
#  (0018, 0020) Scanning Sequence                   CS: 'SE'
#  (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
#  (0018, 0022) Scan Options                        CS: 'SAT1'
#  (0018, 0023) MR Acquisition Type                 CS: '2D'
#  (0018, 0024) Sequence Name                       SH: '*tse2d1_3'
#  (0018, 0025) Angio Flag                          CS: 'N'
#  (0018, 0050) Slice Thickness                     DS: '2.5'
#  (0018, 0080) Repetition Time                     DS: '701.0'
#  (0018, 0081) Echo Time                           DS: '11.0'
#  (0018, 0083) Number of Averages                  DS: '3.0'
#  (0018, 0084) Imaging Frequency                   DS: '123.202865'
#  (0018, 0085) Imaged Nucleus                      SH: '1H'
#  (0018, 0086) Echo Number(s)                      IS: '1'
#  (0018, 0087) Magnetic Field Strength             DS: '3.0'
#  (0018, 0088) Spacing Between Slices              DS: '2.625'
#  (0018, 0089) Number of Phase Encoding Steps      IS: '411'
#  (0018, 0091) Echo Train Length                   IS: '3'
#  (0018, 0093) Percent Sampling                    DS: '100.0'
#  (0018, 0094) Percent Phase Field of View         DS: '100.0'
#  (0018, 0095) Pixel Bandwidth                     DS: '355.0'
#  (0018, 1000) Device Serial Number                LO: '45302'
#  (0018, 1020) Software Versions                   LO: 'syngo MR E11'
#  (0018, 1030) Protocol Name                       LO: 't1_tse_sag'
#  (0018, 1251) Transmit Coil Name                  SH: 'Body'
#  (0018, 1310) Acquisition Matrix                  US: [0, 256, 256, 0]
#  (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
#  (0018, 1314) Flip Angle                          DS: '120.0'
#  (0018, 1315) Variable Flip Angle Flag            CS: 'N'
#  (0018, 1316) SAR                                 DS: '0.51975795973104'
#  (0018, 1318) dB/dt                               DS: '0.0'
#  (0018, 5100) Patient Position                    CS: 'HFS'
#  (0020, 000d) Study Instance UID                  UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#  (0020, 000e) Series Instance UID                 UI: MF-KdaI_mhQcpJTARMSnVyZb7E3f_r8BydrO6Ir7esE=
#  (0020, 0010) Study ID                            SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0020, 0011) Series Number                       IS: '7'
#  (0020, 0012) Acquisition Number                  IS: '1'
#  (0020, 0013) Instance Number                     IS: '14'
#  (0020, 0032) Image Position (Patient)            DS: [-25.430871186239, -88.014193354203, 76.08759045863]
#  (0020, 0037) Image Orientation (Patient)         DS: [0.10712895011114, 0.99214866458433, 0.06453228193409, 0.00578426725438, 0.06428277267649, -0.9979149599988]
#  (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.19.45302.1.20160618152114898.0.0.0
#  (0020, 1040) Position Reference Indicator        LO: ''
#  (0020, 1041) Slice Location                      DS: '-15.929355450269'
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.3125, 0.3125]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 12
#  (0028, 0102) High Bit                            US: 11
#  (0028, 0103) Pixel Representation                US: 0
#  (0028, 0106) Smallest Image Pixel Value          US: 0
#  (0028, 0107) Largest Image Pixel Value           US: 1208
#  (0028, 1050) Window Center                       DS: '373.0'
#  (0028, 1051) Window Width                        DS: '825.0'
#  (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
#  (0040, 0244) Performed Procedure Step Start Date DA: '20160618'
#  (0040, 0245) Performed Procedure Step Start Time TM: '152114.827000'
#  (0040, 0253) Performed Procedure Step ID         SH: '7013955'
#  (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hypophyse'
#  (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#     (0040, 1001) Requested Procedure ID              SH: '7013955'
#     ---------
#  (0040, 0280) Comments on the Performed Procedure ST: ''
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0000) File Meta Information Group Length  UL: 196
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.19.45302.2016061815295720419227549
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.6
#  (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_366'
#  -------------------------------------------------
#  (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
#  (0008, 0012) Instance Creation Date              DA: '20160618'
#  (0008, 0013) Instance Creation Time              TM: '153000.085000'
#  (0008, 0016) SOP Class UID                       UI: MR Image Storage
#  (0008, 0018) SOP Instance UID                    UI: zomL-t-KPbfdr6oR8QxHKga_H_kbwuYx-rany55pZ9k=
#  (0008, 0020) Study Date                          DA: '20160618'
#  (0008, 0021) Series Date                         DA: '20160618'
#  (0008, 0022) Acquisition Date                    DA: '20160618'
#  (0008, 0023) Content Date                        DA: '20160618'
#  (0008, 0030) Study Time                          TM: '152114.745000'
#  (0008, 0031) Series Time                         TM: '153000.061000'
#  (0008, 0032) Acquisition Time                    TM: '152504.065000'
#  (0008, 0033) Content Time                        TM: '153000.085000'
#  (0008, 0050) Accession Number                    SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0008, 0060) Modality                            CS: 'MR'
#  (0008, 0070) Manufacturer                        LO: 'SIEMENS'
#  (0008, 1010) Station Name                        SH: 'KSA33801'
#  (0008, 1030) Study Description                   LO: 'MR Hypophyse'
#  (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#     (0008, 0100) Code Value                          SH: 'MNDSHYP'
#     (0008, 0102) Coding Scheme Designator            SH: 'L'
#     (0008, 0104) Code Meaning                        LO: 'MR Hypophyse'
#     ---------
#  (0008, 103e) Series Description                  LO: 't1_tse_sag'
#  (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
#  (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#     ---------
#  (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: hftXsteDt1i7G90yzzxbi9monIJwZd5iBQMUNAyPyCA=
#     ---------
#  (0008, 1140)  Referenced Image Sequence  3 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: xlvmirMT72APq-niAJSdNqzd7O6x0tsvuMoA0X-pu7c=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 3V47tC-BvUTwoqBk9oRXFs7zhz3ernDaQXOiThncUBk=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#     ---------
#  (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#  (0010, 0020) Patient ID                          LO: 'cxhGTPfptFa_593Kas1wi7iGmnu2nKbklSXoebANACc='
#  (0010, 0040) Patient's Sex                       CS: 'F'
#  (0010, 1010) Patient's Age                       AS: '060Y'
#  (0010, 1020) Patient's Size                      DS: '1.57'
#  (0010, 1030) Patient's Weight                    DS: '81.0'
#  (0010, 21c0) Pregnancy Status                    US: 4
#  (0012, 0062) Patient Identity Removed            CS: 'Yes'
#  (0018, 0015) Body Part Examined                  CS: 'BRAIN'
#  (0018, 0020) Scanning Sequence                   CS: 'SE'
#  (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
#  (0018, 0022) Scan Options                        CS: 'SAT1'
#  (0018, 0023) MR Acquisition Type                 CS: '2D'
#  (0018, 0024) Sequence Name                       SH: '*tse2d1_3'
#  (0018, 0025) Angio Flag                          CS: 'N'
#  (0018, 0050) Slice Thickness                     DS: '2.5'
#  (0018, 0080) Repetition Time                     DS: '701.0'
#  (0018, 0081) Echo Time                           DS: '11.0'
#  (0018, 0083) Number of Averages                  DS: '3.0'
#  (0018, 0084) Imaging Frequency                   DS: '123.202865'
#  (0018, 0085) Imaged Nucleus                      SH: '1H'
#  (0018, 0086) Echo Number(s)                      IS: '1'
#  (0018, 0087) Magnetic Field Strength             DS: '3.0'
#  (0018, 0088) Spacing Between Slices              DS: '2.625'
#  (0018, 0089) Number of Phase Encoding Steps      IS: '411'
#  (0018, 0091) Echo Train Length                   IS: '3'
#  (0018, 0093) Percent Sampling                    DS: '100.0'
#  (0018, 0094) Percent Phase Field of View         DS: '100.0'
#  (0018, 0095) Pixel Bandwidth                     DS: '355.0'
#  (0018, 1000) Device Serial Number                LO: '45302'
#  (0018, 1020) Software Versions                   LO: 'syngo MR E11'
#  (0018, 1030) Protocol Name                       LO: 't1_tse_sag'
#  (0018, 1251) Transmit Coil Name                  SH: 'Body'
#  (0018, 1310) Acquisition Matrix                  US: [0, 256, 256, 0]
#  (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
#  (0018, 1314) Flip Angle                          DS: '120.0'
#  (0018, 1315) Variable Flip Angle Flag            CS: 'N'
#  (0018, 1316) SAR                                 DS: '0.51975795973104'
#  (0018, 1318) dB/dt                               DS: '0.0'
#  (0018, 5100) Patient Position                    CS: 'HFS'
#  (0020, 000d) Study Instance UID                  UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#  (0020, 000e) Series Instance UID                 UI: MF-KdaI_mhQcpJTARMSnVyZb7E3f_r8BydrO6Ir7esE=
#  (0020, 0010) Study ID                            SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0020, 0011) Series Number                       IS: '7'
#  (0020, 0012) Acquisition Number                  IS: '1'
#  (0020, 0013) Instance Number                     IS: '3'
#  (0020, 0032) Image Position (Patient)            DS: [3.2774713659465, -91.111869392945, 76.054452064274]
#  (0020, 0037) Image Orientation (Patient)         DS: [0.10712895011114, 0.99214866458433, 0.06453228193409, 0.00578426725438, 0.06428277267649, -0.9979149599988]
#  (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.19.45302.1.20160618152114898.0.0.0
#  (0020, 1040) Position Reference Indicator        LO: ''
#  (0020, 1041) Slice Location                      DS: '12.945644585883'
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.3125, 0.3125]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 12
#  (0028, 0102) High Bit                            US: 11
#  (0028, 0103) Pixel Representation                US: 0
#  (0028, 0106) Smallest Image Pixel Value          US: 0
#  (0028, 0107) Largest Image Pixel Value           US: 1162
#  (0028, 1050) Window Center                       DS: '393.0'
#  (0028, 1051) Window Width                        DS: '874.0'
#  (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
#  (0040, 0244) Performed Procedure Step Start Date DA: '20160618'
#  (0040, 0245) Performed Procedure Step Start Time TM: '152114.827000'
#  (0040, 0253) Performed Procedure Step ID         SH: '7013955'
#  (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hypophyse'
#  (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#     (0040, 1001) Requested Procedure ID              SH: '7013955'
#     ---------
#  (0040, 0280) Comments on the Performed Procedure ST: ''
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0000) File Meta Information Group Length  UL: 196
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.19.45302.2016061815295720475827550
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.6
#  (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_366'
#  -------------------------------------------------
#  (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
#  (0008, 0012) Instance Creation Date              DA: '20160618'
#  (0008, 0013) Instance Creation Time              TM: '153000.083000'
#  (0008, 0016) SOP Class UID                       UI: MR Image Storage
#  (0008, 0018) SOP Instance UID                    UI: 7EFR9e1JxranAtlUjCo8WFHwE8TYwRjEX9SGzC0qxco=
#  (0008, 0020) Study Date                          DA: '20160618'
#  (0008, 0021) Series Date                         DA: '20160618'
#  (0008, 0022) Acquisition Date                    DA: '20160618'
#  (0008, 0023) Content Date                        DA: '20160618'
#  (0008, 0030) Study Time                          TM: '152114.745000'
#  (0008, 0031) Series Time                         TM: '153000.061000'
#  (0008, 0032) Acquisition Time                    TM: '152504.017500'
#  (0008, 0033) Content Time                        TM: '153000.083000'
#  (0008, 0050) Accession Number                    SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0008, 0060) Modality                            CS: 'MR'
#  (0008, 0070) Manufacturer                        LO: 'SIEMENS'
#  (0008, 1010) Station Name                        SH: 'KSA33801'
#  (0008, 1030) Study Description                   LO: 'MR Hypophyse'
#  (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#     (0008, 0100) Code Value                          SH: 'MNDSHYP'
#     (0008, 0102) Coding Scheme Designator            SH: 'L'
#     (0008, 0104) Code Meaning                        LO: 'MR Hypophyse'
#     ---------
#  (0008, 103e) Series Description                  LO: 't1_tse_sag'
#  (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
#  (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#     ---------
#  (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: hftXsteDt1i7G90yzzxbi9monIJwZd5iBQMUNAyPyCA=
#     ---------
#  (0008, 1140)  Referenced Image Sequence  3 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: xlvmirMT72APq-niAJSdNqzd7O6x0tsvuMoA0X-pu7c=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 3V47tC-BvUTwoqBk9oRXFs7zhz3ernDaQXOiThncUBk=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#     ---------
#  (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#  (0010, 0020) Patient ID                          LO: 'cxhGTPfptFa_593Kas1wi7iGmnu2nKbklSXoebANACc='
#  (0010, 0040) Patient's Sex                       CS: 'F'
#  (0010, 1010) Patient's Age                       AS: '060Y'
#  (0010, 1020) Patient's Size                      DS: '1.57'
#  (0010, 1030) Patient's Weight                    DS: '81.0'
#  (0010, 21c0) Pregnancy Status                    US: 4
#  (0012, 0062) Patient Identity Removed            CS: 'Yes'
#  (0018, 0015) Body Part Examined                  CS: 'BRAIN'
#  (0018, 0020) Scanning Sequence                   CS: 'SE'
#  (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
#  (0018, 0022) Scan Options                        CS: 'SAT1'
#  (0018, 0023) MR Acquisition Type                 CS: '2D'
#  (0018, 0024) Sequence Name                       SH: '*tse2d1_3'
#  (0018, 0025) Angio Flag                          CS: 'N'
#  (0018, 0050) Slice Thickness                     DS: '2.5'
#  (0018, 0080) Repetition Time                     DS: '701.0'
#  (0018, 0081) Echo Time                           DS: '11.0'
#  (0018, 0083) Number of Averages                  DS: '3.0'
#  (0018, 0084) Imaging Frequency                   DS: '123.202865'
#  (0018, 0085) Imaged Nucleus                      SH: '1H'
#  (0018, 0086) Echo Number(s)                      IS: '1'
#  (0018, 0087) Magnetic Field Strength             DS: '3.0'
#  (0018, 0088) Spacing Between Slices              DS: '2.625'
#  (0018, 0089) Number of Phase Encoding Steps      IS: '411'
#  (0018, 0091) Echo Train Length                   IS: '3'
#  (0018, 0093) Percent Sampling                    DS: '100.0'
#  (0018, 0094) Percent Phase Field of View         DS: '100.0'
#  (0018, 0095) Pixel Bandwidth                     DS: '355.0'
#  (0018, 1000) Device Serial Number                LO: '45302'
#  (0018, 1020) Software Versions                   LO: 'syngo MR E11'
#  (0018, 1030) Protocol Name                       LO: 't1_tse_sag'
#  (0018, 1251) Transmit Coil Name                  SH: 'Body'
#  (0018, 1310) Acquisition Matrix                  US: [0, 256, 256, 0]
#  (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
#  (0018, 1314) Flip Angle                          DS: '120.0'
#  (0018, 1315) Variable Flip Angle Flag            CS: 'N'
#  (0018, 1316) SAR                                 DS: '0.51975795973104'
#  (0018, 1318) dB/dt                               DS: '0.0'
#  (0018, 5100) Patient Position                    CS: 'HFS'
#  (0020, 000d) Study Instance UID                  UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#  (0020, 000e) Series Instance UID                 UI: MF-KdaI_mhQcpJTARMSnVyZb7E3f_r8BydrO6Ir7esE=
#  (0020, 0010) Study ID                            SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0020, 0011) Series Number                       IS: '7'
#  (0020, 0012) Acquisition Number                  IS: '1'
#  (0020, 0013) Instance Number                     IS: '5'
#  (0020, 0032) Image Position (Patient)            DS: [-1.9422275399984, -90.548655567719, 76.060477259396]
#  (0020, 0037) Image Orientation (Patient)         DS: [0.10712895011114, 0.99214866458433, 0.06453228193409, 0.00578426725438, 0.06428277267649, -0.9979149599988]
#  (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.19.45302.1.20160618152114898.0.0.0
#  (0020, 1040) Position Reference Indicator        LO: ''
#  (0020, 1041) Slice Location                      DS: '7.6956443206805'
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.3125, 0.3125]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 12
#  (0028, 0102) High Bit                            US: 11
#  (0028, 0103) Pixel Representation                US: 0
#  (0028, 0106) Smallest Image Pixel Value          US: 0
#  (0028, 0107) Largest Image Pixel Value           US: 1238
#  (0028, 1050) Window Center                       DS: '373.0'
#  (0028, 1051) Window Width                        DS: '847.0'
#  (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
#  (0040, 0244) Performed Procedure Step Start Date DA: '20160618'
#  (0040, 0245) Performed Procedure Step Start Time TM: '152114.827000'
#  (0040, 0253) Performed Procedure Step ID         SH: '7013955'
#  (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hypophyse'
#  (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#     (0040, 1001) Requested Procedure ID              SH: '7013955'
#     ---------
#  (0040, 0280) Comments on the Performed Procedure ST: ''
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0000) File Meta Information Group Length  UL: 196
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.19.45302.2016061815295721149027551
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.6
#  (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_366'
#  -------------------------------------------------
#  (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
#  (0008, 0012) Instance Creation Date              DA: '20160618'
#  (0008, 0013) Instance Creation Time              TM: '153000.070000'
#  (0008, 0016) SOP Class UID                       UI: MR Image Storage
#  (0008, 0018) SOP Instance UID                    UI: o7lrP99P_mK64gvsBf8g5ID09Fp-uz228ZRSm0K5Uck=
#  (0008, 0020) Study Date                          DA: '20160618'
#  (0008, 0021) Series Date                         DA: '20160618'
#  (0008, 0022) Acquisition Date                    DA: '20160618'
#  (0008, 0023) Content Date                        DA: '20160618'
#  (0008, 0030) Study Time                          TM: '152114.745000'
#  (0008, 0031) Series Time                         TM: '153000.061000'
#  (0008, 0032) Acquisition Time                    TM: '152503.925000'
#  (0008, 0033) Content Time                        TM: '153000.070000'
#  (0008, 0050) Accession Number                    SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0008, 0060) Modality                            CS: 'MR'
#  (0008, 0070) Manufacturer                        LO: 'SIEMENS'
#  (0008, 1010) Station Name                        SH: 'KSA33801'
#  (0008, 1030) Study Description                   LO: 'MR Hypophyse'
#  (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#     (0008, 0100) Code Value                          SH: 'MNDSHYP'
#     (0008, 0102) Coding Scheme Designator            SH: 'L'
#     (0008, 0104) Code Meaning                        LO: 'MR Hypophyse'
#     ---------
#  (0008, 103e) Series Description                  LO: 't1_tse_sag'
#  (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
#  (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#     ---------
#  (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: hftXsteDt1i7G90yzzxbi9monIJwZd5iBQMUNAyPyCA=
#     ---------
#  (0008, 1140)  Referenced Image Sequence  3 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: xlvmirMT72APq-niAJSdNqzd7O6x0tsvuMoA0X-pu7c=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 3V47tC-BvUTwoqBk9oRXFs7zhz3ernDaQXOiThncUBk=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#     ---------
#  (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#  (0010, 0020) Patient ID                          LO: 'cxhGTPfptFa_593Kas1wi7iGmnu2nKbklSXoebANACc='
#  (0010, 0040) Patient's Sex                       CS: 'F'
#  (0010, 1010) Patient's Age                       AS: '060Y'
#  (0010, 1020) Patient's Size                      DS: '1.57'
#  (0010, 1030) Patient's Weight                    DS: '81.0'
#  (0010, 21c0) Pregnancy Status                    US: 4
#  (0012, 0062) Patient Identity Removed            CS: 'Yes'
#  (0018, 0015) Body Part Examined                  CS: 'BRAIN'
#  (0018, 0020) Scanning Sequence                   CS: 'SE'
#  (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
#  (0018, 0022) Scan Options                        CS: 'SAT1'
#  (0018, 0023) MR Acquisition Type                 CS: '2D'
#  (0018, 0024) Sequence Name                       SH: '*tse2d1_3'
#  (0018, 0025) Angio Flag                          CS: 'N'
#  (0018, 0050) Slice Thickness                     DS: '2.5'
#  (0018, 0080) Repetition Time                     DS: '701.0'
#  (0018, 0081) Echo Time                           DS: '11.0'
#  (0018, 0083) Number of Averages                  DS: '3.0'
#  (0018, 0084) Imaging Frequency                   DS: '123.202865'
#  (0018, 0085) Imaged Nucleus                      SH: '1H'
#  (0018, 0086) Echo Number(s)                      IS: '1'
#  (0018, 0087) Magnetic Field Strength             DS: '3.0'
#  (0018, 0088) Spacing Between Slices              DS: '2.625'
#  (0018, 0089) Number of Phase Encoding Steps      IS: '411'
#  (0018, 0091) Echo Train Length                   IS: '3'
#  (0018, 0093) Percent Sampling                    DS: '100.0'
#  (0018, 0094) Percent Phase Field of View         DS: '100.0'
#  (0018, 0095) Pixel Bandwidth                     DS: '355.0'
#  (0018, 1000) Device Serial Number                LO: '45302'
#  (0018, 1020) Software Versions                   LO: 'syngo MR E11'
#  (0018, 1030) Protocol Name                       LO: 't1_tse_sag'
#  (0018, 1251) Transmit Coil Name                  SH: 'Body'
#  (0018, 1310) Acquisition Matrix                  US: [0, 256, 256, 0]
#  (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
#  (0018, 1314) Flip Angle                          DS: '120.0'
#  (0018, 1315) Variable Flip Angle Flag            CS: 'N'
#  (0018, 1316) SAR                                 DS: '0.51975795973104'
#  (0018, 1318) dB/dt                               DS: '0.0'
#  (0018, 5100) Patient Position                    CS: 'HFS'
#  (0020, 000d) Study Instance UID                  UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#  (0020, 000e) Series Instance UID                 UI: MF-KdaI_mhQcpJTARMSnVyZb7E3f_r8BydrO6Ir7esE=
#  (0020, 0010) Study ID                            SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0020, 0011) Series Number                       IS: '7'
#  (0020, 0012) Acquisition Number                  IS: '1'
#  (0020, 0013) Instance Number                     IS: '9'
#  (0020, 0032) Image Position (Patient)            DS: [-12.381624875051, -89.422227917267, 76.07252753043]
#  (0020, 0037) Image Orientation (Patient)         DS: [0.10712895011114, 0.99214866458433, 0.06453228193409, 0.00578426725438, 0.06428277267649, -0.9979149599988]
#  (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.19.45302.1.20160618152114898.0.0.0
#  (0020, 1040) Position Reference Indicator        LO: ''
#  (0020, 1041) Slice Location                      DS: '-2.8043557355021'
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.3125, 0.3125]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 12
#  (0028, 0102) High Bit                            US: 11
#  (0028, 0103) Pixel Representation                US: 0
#  (0028, 0106) Smallest Image Pixel Value          US: 0
#  (0028, 0107) Largest Image Pixel Value           US: 1184
#  (0028, 1050) Window Center                       DS: '361.0'
#  (0028, 1051) Window Width                        DS: '823.0'
#  (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
#  (0040, 0244) Performed Procedure Step Start Date DA: '20160618'
#  (0040, 0245) Performed Procedure Step Start Time TM: '152114.827000'
#  (0040, 0253) Performed Procedure Step ID         SH: '7013955'
#  (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hypophyse'
#  (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#     (0040, 1001) Requested Procedure ID              SH: '7013955'
#     ---------
#  (0040, 0280) Comments on the Performed Procedure ST: ''
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0000) File Meta Information Group Length  UL: 196
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.19.45302.2016061815295725071327556
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.6
#  (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_366'
#  -------------------------------------------------
#  (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
#  (0008, 0012) Instance Creation Date              DA: '20160618'
#  (0008, 0013) Instance Creation Time              TM: '153000.072000'
#  (0008, 0016) SOP Class UID                       UI: MR Image Storage
#  (0008, 0018) SOP Instance UID                    UI: hocC4JjoOvzIbkEz3px-52yGVZliPejrcmOa3fwq__s=
#  (0008, 0020) Study Date                          DA: '20160618'
#  (0008, 0021) Series Date                         DA: '20160618'
#  (0008, 0022) Acquisition Date                    DA: '20160618'
#  (0008, 0023) Content Date                        DA: '20160618'
#  (0008, 0030) Study Time                          TM: '152114.745000'
#  (0008, 0031) Series Time                         TM: '153000.061000'
#  (0008, 0032) Acquisition Time                    TM: '152503.970000'
#  (0008, 0033) Content Time                        TM: '153000.072000'
#  (0008, 0050) Accession Number                    SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0008, 0060) Modality                            CS: 'MR'
#  (0008, 0070) Manufacturer                        LO: 'SIEMENS'
#  (0008, 1010) Station Name                        SH: 'KSA33801'
#  (0008, 1030) Study Description                   LO: 'MR Hypophyse'
#  (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#     (0008, 0100) Code Value                          SH: 'MNDSHYP'
#     (0008, 0102) Coding Scheme Designator            SH: 'L'
#     (0008, 0104) Code Meaning                        LO: 'MR Hypophyse'
#     ---------
#  (0008, 103e) Series Description                  LO: 't1_tse_sag'
#  (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
#  (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#     ---------
#  (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: hftXsteDt1i7G90yzzxbi9monIJwZd5iBQMUNAyPyCA=
#     ---------
#  (0008, 1140)  Referenced Image Sequence  3 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: xlvmirMT72APq-niAJSdNqzd7O6x0tsvuMoA0X-pu7c=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 3V47tC-BvUTwoqBk9oRXFs7zhz3ernDaQXOiThncUBk=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#     ---------
#  (0008, 1155) Referenced SOP Instance UID         UI: 2WrHXQIvSJfxbsn0B5zzeWKOL-7fE9_xek4-dTqmAbY=
#  (0010, 0020) Patient ID                          LO: 'cxhGTPfptFa_593Kas1wi7iGmnu2nKbklSXoebANACc='
#  (0010, 0040) Patient's Sex                       CS: 'F'
#  (0010, 1010) Patient's Age                       AS: '060Y'
#  (0010, 1020) Patient's Size                      DS: '1.57'
#  (0010, 1030) Patient's Weight                    DS: '81.0'
#  (0010, 21c0) Pregnancy Status                    US: 4
#  (0012, 0062) Patient Identity Removed            CS: 'Yes'
#  (0018, 0015) Body Part Examined                  CS: 'BRAIN'
#  (0018, 0020) Scanning Sequence                   CS: 'SE'
#  (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
#  (0018, 0022) Scan Options                        CS: 'SAT1'
#  (0018, 0023) MR Acquisition Type                 CS: '2D'
#  (0018, 0024) Sequence Name                       SH: '*tse2d1_3'
#  (0018, 0025) Angio Flag                          CS: 'N'
#  (0018, 0050) Slice Thickness                     DS: '2.5'
#  (0018, 0080) Repetition Time                     DS: '701.0'
#  (0018, 0081) Echo Time                           DS: '11.0'
#  (0018, 0083) Number of Averages                  DS: '3.0'
#  (0018, 0084) Imaging Frequency                   DS: '123.202865'
#  (0018, 0085) Imaged Nucleus                      SH: '1H'
#  (0018, 0086) Echo Number(s)                      IS: '1'
#  (0018, 0087) Magnetic Field Strength             DS: '3.0'
#  (0018, 0088) Spacing Between Slices              DS: '2.625'
#  (0018, 0089) Number of Phase Encoding Steps      IS: '411'
#  (0018, 0091) Echo Train Length                   IS: '3'
#  (0018, 0093) Percent Sampling                    DS: '100.0'
#  (0018, 0094) Percent Phase Field of View         DS: '100.0'
#  (0018, 0095) Pixel Bandwidth                     DS: '355.0'
# ...
#  (0008, 0050) Accession Number                    SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0008, 0060) Modality                            CS: 'MR'
#  (0008, 0070) Manufacturer                        LO: 'SIEMENS'
#  (0008, 1010) Station Name                        SH: 'KSA33801'
#  (0008, 1030) Study Description                   LO: 'MR Hypophyse'
#  (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#     (0008, 0100) Code Value                          SH: 'MNDSHYP'
#     (0008, 0102) Coding Scheme Designator            SH: 'L'
#     (0008, 0104) Code Meaning                        LO: 'MR Hypophyse'
#     ---------
#  (0008, 103e) Series Description                  LO: 't1_tse_fs_cor'
#  (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
#  (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#     ---------
#  (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: hftXsteDt1i7G90yzzxbi9monIJwZd5iBQMUNAyPyCA=
#     ---------
#  (0008, 1140)  Referenced Image Sequence  3 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: zxpYj7mM85bPbvfa9V-m2IN4HEb8-BeaaqVw11e44mY=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 3V47tC-BvUTwoqBk9oRXFs7zhz3ernDaQXOiThncUBk=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: xlvmirMT72APq-niAJSdNqzd7O6x0tsvuMoA0X-pu7c=
#     ---------
#  (0008, 1155) Referenced SOP Instance UID         UI: xlvmirMT72APq-niAJSdNqzd7O6x0tsvuMoA0X-pu7c=
#  (0010, 0020) Patient ID                          LO: 'cxhGTPfptFa_593Kas1wi7iGmnu2nKbklSXoebANACc='
#  (0010, 0040) Patient's Sex                       CS: 'F'
#  (0010, 1010) Patient's Age                       AS: '060Y'
#  (0010, 1020) Patient's Size                      DS: '1.57'
#  (0010, 1030) Patient's Weight                    DS: '81.0'
#  (0010, 21c0) Pregnancy Status                    US: 4
#  (0012, 0062) Patient Identity Removed            CS: 'Yes'
#  (0018, 0010) Contrast/Bolus Agent                LO: 'KM i.v.'
#  (0018, 0015) Body Part Examined                  CS: 'BRAIN'
#  (0018, 0020) Scanning Sequence                   CS: 'SE'
#  (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
#  (0018, 0022) Scan Options                        CS: 'FS'
#  (0018, 0023) MR Acquisition Type                 CS: '2D'
#  (0018, 0024) Sequence Name                       SH: '*tse2d1_3'
#  (0018, 0025) Angio Flag                          CS: 'N'
#  (0018, 0050) Slice Thickness                     DS: '2.0'
#  (0018, 0080) Repetition Time                     DS: '500.0'
#  (0018, 0081) Echo Time                           DS: '9.5'
#  (0018, 0083) Number of Averages                  DS: '3.0'
#  (0018, 0084) Imaging Frequency                   DS: '123.202787'
#  (0018, 0085) Imaged Nucleus                      SH: '1H'
#  (0018, 0086) Echo Number(s)                      IS: '1'
#  (0018, 0087) Magnetic Field Strength             DS: '3.0'
#  (0018, 0088) Spacing Between Slices              DS: '2.0'
#  (0018, 0089) Number of Phase Encoding Steps      IS: '279'
#  (0018, 0091) Echo Train Length                   IS: '3'
#  (0018, 0093) Percent Sampling                    DS: '90.0'
#  (0018, 0094) Percent Phase Field of View         DS: '100.0'
#  (0018, 0095) Pixel Bandwidth                     DS: '260.0'
#  (0018, 1000) Device Serial Number                LO: '45302'
#  (0018, 1020) Software Versions                   LO: 'syngo MR E11'
#  (0018, 1030) Protocol Name                       LO: 't1_tse_fs_cor'
#  (0018, 1041) Contrast/Bolus Volume               DS: '0.0'
#  (0018, 1044) Contrast/Bolus Total Dose           DS: '0.0'
#  (0018, 1048) Contrast/Bolus Ingredient           CS: ''
#  (0018, 1049) Contrast/Bolus Ingredient Concentra DS: '0.0'
#  (0018, 1251) Transmit Coil Name                  SH: 'Body'
#  (0018, 1310) Acquisition Matrix                  US: [0, 256, 230, 0]
#  (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
#  (0018, 1314) Flip Angle                          DS: '135.0'
#  (0018, 1315) Variable Flip Angle Flag            CS: 'N'
#  (0018, 1316) SAR                                 DS: '0.33319439470251'
#  (0018, 1318) dB/dt                               DS: '0.0'
#  (0018, 5100) Patient Position                    CS: 'HFS'
#  (0020, 000d) Study Instance UID                  UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#  (0020, 000e) Series Instance UID                 UI: IrShTDTH28IcyOtCGsrruKyM8ECrF34u7oCAjozgzwY=
#  (0020, 0010) Study ID                            SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0020, 0011) Series Number                       IS: '11'
#  (0020, 0012) Acquisition Number                  IS: '1'
#  (0020, 0013) Instance Number                     IS: '12'
#  (0020, 0032) Image Position (Patient)            DS: [-75.368712753033, 66.052649090757, 62.048194002327]
#  (0020, 0037) Image Orientation (Patient)         DS: [0.99392674220142, -0.1093965752967, 0.01191723332979, -0.0622877656427, -0.6485581064931, -0.7586122967322]
#  (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.19.45302.1.20160618152114898.0.0.0
#  (0020, 1040) Position Reference Indicator        LO: ''
#  (0020, 1041) Slice Location                      DS: '2.4973949773384'
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 256
#  (0028, 0011) Columns                             US: 256
#  (0028, 0030) Pixel Spacing                       DS: [0.625, 0.625]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 12
#  (0028, 0102) High Bit                            US: 11
#  (0028, 0103) Pixel Representation                US: 0
#  (0028, 0106) Smallest Image Pixel Value          US: 0
#  (0028, 0107) Largest Image Pixel Value           US: 1302
#  (0028, 1050) Window Center                       DS: '452.0'
#  (0028, 1051) Window Width                        DS: '961.0'
#  (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
#  (0040, 0244) Performed Procedure Step Start Date DA: '20160618'
#  (0040, 0245) Performed Procedure Step Start Time TM: '152114.827000'
#  (0040, 0253) Performed Procedure Step ID         SH: '7013955'
#  (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hypophyse'
#  (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#     (0040, 1001) Requested Procedure ID              SH: '7013955'
#     ---------
#  (0040, 0280) Comments on the Performed Procedure ST: ''
#  (7fe0, 0010) Pixel Data                          OW: Array of 131072 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0000) File Meta Information Group Length  UL: 196
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.19.45302.2016061815492647299827901
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.6
#  (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_366'
#  -------------------------------------------------
#  (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
#  (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
#  (0008, 0012) Instance Creation Date              DA: '20160618'
#  (0008, 0013) Instance Creation Time              TM: '154926.563000'
#  (0008, 0016) SOP Class UID                       UI: MR Image Storage
#  (0008, 0018) SOP Instance UID                    UI: _nVq8VV3F79MHk8CS23fmM1xTIop9e0eLkK9gk95MXI=
#  (0008, 0020) Study Date                          DA: '20160618'
#  (0008, 0021) Series Date                         DA: '20160618'
#  (0008, 0022) Acquisition Date                    DA: '20160618'
#  (0008, 0023) Content Date                        DA: '20160618'
#  (0008, 0030) Study Time                          TM: '152114.745000'
#  (0008, 0031) Series Time                         TM: '154708.695000'
#  (0008, 0032) Acquisition Time                    TM: '154705.930000'
#  (0008, 0033) Content Time                        TM: '154926.563000'
#  (0008, 0050) Accession Number                    SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0008, 0060) Modality                            CS: 'MR'
#  (0008, 0070) Manufacturer                        LO: 'SIEMENS'
#  (0008, 1010) Station Name                        SH: 'KSA33801'
#  (0008, 1030) Study Description                   LO: 'MR Hypophyse'
#  (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#     (0008, 0100) Code Value                          SH: 'MNDSHYP'
#     (0008, 0102) Coding Scheme Designator            SH: 'L'
#     (0008, 0104) Code Meaning                        LO: 'MR Hypophyse'
#     ---------
#  (0008, 103e) Series Description                  LO: 't1_tse_fs_cor'
#  (0008, 1090) Manufacturer's Model Name           LO: 'Skyra'
#  (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#     ---------
#  (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#     (0008, 1155) Referenced SOP Instance UID         UI: hftXsteDt1i7G90yzzxbi9monIJwZd5iBQMUNAyPyCA=
#     ---------
#  (0008, 1140)  Referenced Image Sequence  3 item(s) ----
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: zxpYj7mM85bPbvfa9V-m2IN4HEb8-BeaaqVw11e44mY=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: 3V47tC-BvUTwoqBk9oRXFs7zhz3ernDaQXOiThncUBk=
#     ---------
#     (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#     (0008, 1155) Referenced SOP Instance UID         UI: xlvmirMT72APq-niAJSdNqzd7O6x0tsvuMoA0X-pu7c=
#     ---------
#  (0008, 1155) Referenced SOP Instance UID         UI: xlvmirMT72APq-niAJSdNqzd7O6x0tsvuMoA0X-pu7c=
#  (0010, 0020) Patient ID                          LO: 'cxhGTPfptFa_593Kas1wi7iGmnu2nKbklSXoebANACc='
#  (0010, 0040) Patient's Sex                       CS: 'F'
#  (0010, 1010) Patient's Age                       AS: '060Y'
#  (0010, 1020) Patient's Size                      DS: '1.57'
#  (0010, 1030) Patient's Weight                    DS: '81.0'
#  (0010, 21c0) Pregnancy Status                    US: 4
#  (0012, 0062) Patient Identity Removed            CS: 'Yes'
#  (0018, 0010) Contrast/Bolus Agent                LO: 'KM i.v.'
#  (0018, 0015) Body Part Examined                  CS: 'BRAIN'
#  (0018, 0020) Scanning Sequence                   CS: 'SE'
#  (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
#  (0018, 0022) Scan Options                        CS: 'FS'
#  (0018, 0023) MR Acquisition Type                 CS: '2D'
#  (0018, 0024) Sequence Name                       SH: '*tse2d1_3'
#  (0018, 0025) Angio Flag                          CS: 'N'
#  (0018, 0050) Slice Thickness                     DS: '2.0'
#  (0018, 0080) Repetition Time                     DS: '500.0'
#  (0018, 0081) Echo Time                           DS: '9.5'
#  (0018, 0083) Number of Averages                  DS: '3.0'
#  (0018, 0084) Imaging Frequency                   DS: '123.202787'
#  (0018, 0085) Imaged Nucleus                      SH: '1H'
#  (0018, 0086) Echo Number(s)                      IS: '1'
#  (0018, 0087) Magnetic Field Strength             DS: '3.0'
#  (0018, 0088) Spacing Between Slices              DS: '2.0'
#  (0018, 0089) Number of Phase Encoding Steps      IS: '279'
#  (0018, 0091) Echo Train Length                   IS: '3'
#  (0018, 0093) Percent Sampling                    DS: '90.0'
#  (0018, 0094) Percent Phase Field of View         DS: '100.0'
#  (0018, 0095) Pixel Bandwidth                     DS: '260.0'
#  (0018, 1000) Device Serial Number                LO: '45302'
#  (0018, 1020) Software Versions                   LO: 'syngo MR E11'
#  (0018, 1030) Protocol Name                       LO: 't1_tse_fs_cor'
#  (0018, 1041) Contrast/Bolus Volume               DS: '0.0'
#  (0018, 1044) Contrast/Bolus Total Dose           DS: '0.0'
#  (0018, 1048) Contrast/Bolus Ingredient           CS: ''
#  (0018, 1049) Contrast/Bolus Ingredient Concentra DS: '0.0'
#  (0018, 1251) Transmit Coil Name                  SH: 'Body'
#  (0018, 1310) Acquisition Matrix                  US: [0, 256, 230, 0]
#  (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
#  (0018, 1314) Flip Angle                          DS: '135.0'
#  (0018, 1315) Variable Flip Angle Flag            CS: 'N'
#  (0018, 1316) SAR                                 DS: '0.33319439470251'
#  (0018, 1318) dB/dt                               DS: '0.0'
#  (0018, 5100) Patient Position                    CS: 'HFS'
#  (0020, 000d) Study Instance UID                  UI: UprKoULIkwO0af6ITBFQ9V1gbGr-A79ciN6Vw81VYkQ=
#  (0020, 000e) Series Instance UID                 UI: IrShTDTH28IcyOtCGsrruKyM8ECrF34u7oCAjozgzwY=
#  (0020, 0010) Study ID                            SH: '2iIfIR46T4kEC5HHyZB9iSkOWe36TqcMMODg5XrsAbg='
#  (0020, 0011) Series Number                       IS: '11'
#  (0020, 0012) Acquisition Number                  IS: '1'
#  (0020, 0013) Instance Number                     IS: '14'
#  (0020, 0032) Image Position (Patient)            DS: [-75.005838364338, 69.06569964694, 59.442460607704]
#  (0020, 0037) Image Orientation (Patient)         DS: [0.99392674220142, -0.1093965752967, 0.01191723332979, -0.0622877656427, -0.6485581064931, -0.7586122967322]
#  (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.19.45302.1.20160618152114898.0.0.0
#  (0020, 1040) Position Reference Indicator        LO: ''
#  (0020, 1041) Slice Location                      DS: '6.4973947273305'
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 256
#  (0028, 0011) Columns                             US: 256
#  (0028, 0030) Pixel Spacing                       DS: [0.625, 0.625]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 12
#  (0028, 0102) High Bit                            US: 11
#  (0028, 0103) Pixel Representation                US: 0
#  (0028, 0106) Smallest Image Pixel Value          US: 0
#  (0028, 0107) Largest Image Pixel Value           US: 1377
#  (0028, 1050) Window Center                       DS: '465.0'
#  (0028, 1051) Window Width                        DS: '978.0'
#  (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
#  (0040, 0244) Performed Procedure Step Start Date DA: '20160618'
#  (0040, 0245) Performed Procedure Step Start Time TM: '152114.827000'
#  (0040, 0253) Performed Procedure Step ID         SH: '7013955'
#  (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hypophyse'
#  (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#     (0040, 1001) Requested Procedure ID              SH: '7013955'
#     ---------
#  (0040, 0280) Comments on the Performed Procedure ST: ''
#  (7fe0, 0010) Pixel Data                          OW: Array of 131072 elements]

# %%
def save_files(slices,file,slice_description_to_use=slice_description_to_use)
    for description in slice_description_to_use:
        array_list = np.array([dcm.pixel_array for dcm in slices_sort_and_selectet(slices,description)])
        volume_3d = np.stack(array_list, axis=-1)
        affine = np.eye(4)
        nifti_img = nib.Nifti1Image(volume_3d, affine)
        nib.save(nifti_img, f'../raw_data/nii_files/{description}/{str(file)}.nii')

# %%
import shutil
folder_path = 'TODO'

# Remove the folder along with all its contents
shutil.rmtree(folder_path)

# %%
slice_t2_cor = slices_sort_and_selectet(slices,"t2_tse_fs_cor")
visualize_slices(slice_t2_cor) # 7 - 9 Relevant evtl bei 125 - 250 y-achse 100 - 300 x- achse
# Out:
# interactive(children=(IntSlider(value=7, description='i', max=14), Output()), _dom_classes=('widget-interact',…

# %%
slice_t1_cor = slices_sort_and_selectet(slices,"t1_tse_fs_cor")
visualize_slices(slice_t1_cor) # (6) 7,8 (9)
# Out:
# interactive(children=(IntSlider(value=7, description='i', max=14), Output()), _dom_classes=('widget-interact',…

# %%
t1_tse_cor= slices_sort_and_selectet(slices,"t1_tse_sag")
visualize_slices(t1_tse_cor)
# Out:
# interactive(children=(IntSlider(value=7, description='i', max=14), Output()), _dom_classes=('widget-interact',…

# %%
slice_t2_sag= slices_sort_and_selectet(slices,"t2_tse_fs_sag")
visualize_slices(slice_t2_sag) # 4-9 y-achse 125 - 250 x achse 100 -300
# Out:
# interactive(children=(IntSlider(value=7, description='i', max=14), Output()), _dom_classes=('widget-interact',…

# %%
# Read the DICOM files and stack them into a single 3D numpy array
array_list = np.array([dcm.pixel_array for dcm in slices_sort_and_selectet(slices,"t1_mprage_we_sag_MPR_cor")]).transpose((0,1,2))
#array_list = pad_array(array_list,axis= 1,padd_size=150)
array_list= np.rot90(array_list,k=45, axes=(1,2))
print(array_list.shape)
volume_3d = np.stack(array_list, axis=-1)

# Create a NIfTI image (you might need to provide the correct affine transformation)
affine = np.eye(4)  # This is a placeholder; you may need the actual affine from DICOM headers
nifti_img = nib.Nifti1Image(volume_3d, affine)

# Save the NIfTI image to a file
nib.save(nifti_img, '../raw_data/nii_files/test.nii')
# Out:
# (200, 267, 267)

# %%
array_list = np.array([dcm.pixel_array for dcm in slices_sort_and_selectet(slices,"t1_mprage_we_sag_MPR_cor")])
volume_3d = np.stack(array_list, axis=-1)
nifti_img = nib.Nifti1Image(volume_3d, affine)
nib.save(nifti_img, '../raw_data/nii_files/test.nii')

# %%
def show_slice(i):
    plt.imshow(array_list[:,:,i], cmap='gray')
    plt.show()

interact(show_slice, i=(0, array_list.shape[2]-1))
# Out:
# interactive(children=(IntSlider(value=133, description='i', max=266), Output()), _dom_classes=('widget-interac…
# <function __main__.show_slice(i)>
